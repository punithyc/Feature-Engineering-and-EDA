# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv("C:\\Users\\punith yc\\Downloads\\HousingData.csv")

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
dataset.rename(columns={'MEDV':'price'},inplace=True)

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'price'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (506, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
dataset.describe(include='all')
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# price       0
# dtype: int64

# %%
p_of_null=dataset['CRIM'].isnull().sum()/len(dataset)

# %%
p_of_null
# Out:
# 0.039525691699604744

# %%
p2_of_null=dataset['ZN'].isnull().sum()/len(dataset)

# %%
p2_of_null
# Out:
# 0.039525691699604744

# %%
p3_of_null=dataset['INDUS'].isnull().sum()/len(dataset)

# %%
p3_of_null
# Out:
# 0.039525691699604744

# %%
p4_of_null=dataset['CHAS'].isnull().sum()/len(dataset)

# %%
p4_of_null
# Out:
# 0.039525691699604744

# %%
p5_of_null=dataset['AGE'].isnull().sum()/len(dataset)

# %%
p5_of_null
# Out:
# 0.039525691699604744

# %%
p6_of_null=dataset['LSTAT'].isnull().sum()/len(dataset)

# %%
p6_of_null
# Out:
# 0.039525691699604744

# %%
dataset.dropna()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
sns.distplot(dataset['AGE'])
print(dataset['AGE'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1077131261.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['AGE'])
# -0.5824700575056604

# %%
sns.distplot(dataset['B'])
print(dataset['B'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2666183369.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['B'])
# -2.8903737121414492

# %%
dataset['B']=np.sqrt(dataset['B'])

# %%
sns.distplot(dataset['B'])
print(dataset['B'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2666183369.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['B'])
# -3.3562187558155143

# %%
sns.distplot(dataset['CHAS'])
print(dataset['CHAS'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\295559976.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['CHAS'])
# 3.382293166246438

# %%
dataset['CHAS']=np.sqrt(dataset['CHAS'])

# %%
sns.distplot(dataset['CHAS'])
print(dataset['CHAS'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\295559976.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['CHAS'])
# 3.382293166246438

# %%
sns.distplot(dataset['CRIM'])
print(dataset['CRIM'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\3313072065.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['CRIM'])
# 5.2128426499800975

# %%
sns.distplot(dataset['DIS'])
print(dataset['DIS'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\445527607.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['DIS'])
# 1.0117805793009007

# %%
dataset['DIS']=np.sqrt(dataset['DIS'])

# %%
sns.distplot(dataset['DIS'])
print(dataset['DIS'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\445527607.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['DIS'])
# 0.5644238427865821

# %%
sns.distplot(dataset['INDUS'])
print(dataset['INDUS'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1459770683.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['INDUS'])
# 0.30372218758107833

# %%
sns.distplot(dataset['LSTAT'])
print(dataset['LSTAT'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\3962283085.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['LSTAT'])
# 0.908891836957813

# %%
sns.distplot(dataset['NOX'])
print(dataset['NOX'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1860184329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['NOX'])
# 0.7293079225348787

# %%
sns.distplot(dataset['PTRATIO'])
print(dataset['PTRATIO'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1539591119.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['PTRATIO'])
# -0.8023249268537809

# %%
sns.distplot(dataset['RAD'])
print(dataset['RAD'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1687672487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['RAD'])
# 1.0048146482182057

# %%
dataset['RAD']=np.sqrt(dataset['RAD'])

# %%
sns.distplot(dataset['RAD'])
print(dataset['RAD'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\1687672487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['RAD'])
# 0.8238438790801812

# %%
sns.distplot(dataset['RM'])
print(dataset['RM'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\237098067.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['RM'])
# 0.40361213328874385

# %%
sns.distplot(dataset['TAX'])
print(dataset['TAX'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2556304967.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['TAX'])
# 0.669955941795016

# %%
sns.distplot(dataset['ZN'])
print(dataset['ZN'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2099318560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ZN'])
# 2.2566126051408197

# %%
dataset['ZN']=np.sqrt(dataset['ZN'])

# %%
sns.distplot(dataset['ZN'])
print(dataset['ZN'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2099318560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ZN'])
# 1.518094633468123

# %%
sns.distplot(dataset['price'])
print(dataset['price'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2861199786.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['price'])
# 1.1080984082549072

# %%
dataset['price']=np.sqrt(dataset['price'])

# %%
sns.distplot(dataset['price'])
print(dataset['price'].skew())
# Out:
# C:\Users\punith yc\AppData\Local\Temp\ipykernel_29080\2861199786.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['price'])
# 0.43893531933950786

# %%
plt.boxplot(dataset['price'])
plt.show()

# %%
sns.boxplot(dataset['price'])
# Out:
# <Axes: >

# %%
sns.boxplot(dataset['AGE'])
# Out:
# <Axes: >

# %%
sns.boxplot(dataset['B'])
# Out:
# <Axes: >

# %%
sns.boxplot(dataset['CHAS'])
# Out:
# <Axes: >
